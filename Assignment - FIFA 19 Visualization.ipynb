# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data.csv')

print ('Data read into a pandas dataframe!')
# Out:
# Data read into a pandas dataframe!

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      ID                Name  Age  \
# 18202       18202  238813        J. Lundstram   19
# 18203       18203  243165  N. Christoffersson   19
# 18204       18204  241638           B. Worman   16
# 18205       18205  246268      D. Walker-Rice   17
# 18206       18206  246269           G. Nugent   16
#
#                                                 Photo Nationality  \
# 18202  https://cdn.sofifa.org/players/4/19/238813.png     England
# 18203  https://cdn.sofifa.org/players/4/19/243165.png      Sweden
# 18204  https://cdn.sofifa.org/players/4/19/241638.png     England
# 18205  https://cdn.sofifa.org/players/4/19/246268.png     England
# 18206  https://cdn.sofifa.org/players/4/19/246269.png     England
#
#                                       Flag  Overall  Potential  \
# 18202  https://cdn.sofifa.org/flags/14.png       47         65
# 18203  https://cdn.sofifa.org/flags/46.png       47         63
# 18204  https://cdn.sofifa.org/flags/14.png       47         67
# ...

# %%
df.columns.values
# Out:
# array(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage',
#        'Special', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Body Type', 'Real Face',
#        'Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 'RS', 'LW',
#        'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM',
#        'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'Crossing', 'Finishing', 'HeadingAccuracy',
#        'ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy',
#        'LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
#        'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping',
#        'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions',
# ...

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.drop(['Unnamed: 0','Photo','Flag', 'Club Logo'], axis=1, inplace=True)
df.head(2)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
#
#            Club    Value   Wage  Special  ... Composure  Marking  \
# 0  FC Barcelona  €110.5M  €565K     2202  ...      96.0     33.0
# 1      Juventus     €77M  €405K     2228  ...      95.0     28.0
#
#    StandingTackle  SlidingTackle GKDiving GKHandling GKKicking GKPositioning  \
# 0            28.0           26.0      6.0       11.0      15.0          14.0
# 1            31.0           23.0      7.0       11.0      15.0          14.0
#
#    GKReflexes Release Clause
# 0         8.0        €226.5M
# 1        11.0        €127.1M
#
# [2 rows x 85 columns]

# %%
df.Club.unique()
# Out:
# array(['FC Barcelona', 'Juventus', 'Paris Saint-Germain',
#        'Manchester United', 'Manchester City', 'Chelsea', 'Real Madrid',
#        'Atlético Madrid', 'FC Bayern München', 'Tottenham Hotspur',
#        'Liverpool', 'Napoli', 'Arsenal', 'Milan', 'Inter', 'Lazio',
#        'Borussia Dortmund', 'Vissel Kobe', 'Olympique Lyonnais', 'Roma',
#        'Valencia CF', 'Guangzhou Evergrande Taobao FC', 'FC Porto',
#        'FC Schalke 04', 'Beşiktaş JK', 'LA Galaxy', 'Sporting CP',
#        'Real Betis', 'Olympique de Marseille', 'RC Celta',
#        'Bayer 04 Leverkusen', 'Real Sociedad', 'Villarreal CF',
#        'Sevilla FC', 'SL Benfica', 'AS Saint-Étienne', 'AS Monaco',
#        'Leicester City', 'Atalanta', 'Grêmio', 'Atlético Mineiro',
#        'RB Leipzig', 'Ajax', 'Dalian YiFang FC', 'Everton',
#        'West Ham United', '1. FC Köln', 'TSG 1899 Hoffenheim',
#        'Shanghai SIPG FC', 'OGC Nice', 'Al Nassr',
#        'Wolverhampton Wanderers', 'Borussia Mönchengladbach',
# ...

# %%
df.Nationality.unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
df.set_index('Name', inplace=True)

# %%
df.head()
# Out:
#                        ID  Age Nationality  Overall  Potential  \
# Name
# L. Messi           158023   31   Argentina       94         94
# Cristiano Ronaldo   20801   33    Portugal       94         94
# Neymar Jr          190871   26      Brazil       92         93
# De Gea             193080   27       Spain       91         93
# K. De Bruyne       192985   27     Belgium       91         92
#
#                                   Club    Value   Wage  Special  \
# Name
# L. Messi                  FC Barcelona  €110.5M  €565K     2202
# Cristiano Ronaldo             Juventus     €77M  €405K     2228
# Neymar Jr          Paris Saint-Germain  €118.5M  €290K     2143
# De Gea               Manchester United     €72M  €260K     1471
# K. De Bruyne           Manchester City    €102M  €355K     2281
#
#                   Preferred Foot  ...  Composure  Marking  StandingTackle  \
# Name                              ...
# ...

# %%
df['Overall'].describe()
# Out:
# count    18207.000000
# mean        66.238699
# std          6.908930
# min         46.000000
# 25%         62.000000
# 50%         66.000000
# 75%         71.000000
# max         94.000000
# Name: Overall, dtype: float64

# %%
data_overall94 = df[df['Overall'] == 94]
data_overall94.head()
# Out:
#                        ID  Age Nationality  Overall  Potential          Club  \
# Name
# L. Messi           158023   31   Argentina       94         94  FC Barcelona
# Cristiano Ronaldo   20801   33    Portugal       94         94      Juventus
#
#                      Value   Wage  Special Preferred Foot  ...  Composure  \
# Name                                                       ...
# L. Messi           €110.5M  €565K     2202           Left  ...       96.0
# Cristiano Ronaldo     €77M  €405K     2228          Right  ...       95.0
#
#                    Marking  StandingTackle SlidingTackle GKDiving GKHandling  \
# Name
# L. Messi              33.0            28.0          26.0      6.0       11.0
# Cristiano Ronaldo     28.0            31.0          23.0      7.0       11.0
#
#                   GKKicking  GKPositioning GKReflexes Release Clause
# Name
# L. Messi               15.0           14.0        8.0        €226.5M
# ...

# %%
df.columns = list(map(str, df.columns))

# %%
position = ['LS', 'ST', 'RS', 'LW','LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM','RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB','CB','RCB', 'RB']
position
# Out:
# ['LS',
#  'ST',
#  'RS',
#  'LW',
#  'LF',
#  'CF',
#  'RF',
#  'RW',
#  'LAM',
#  'CAM',
#  'RAM',
#  'LM',
#  'LCM',
#  'CM',
#  'RCM',
#  'RM',
#  'LWB',
#  'LDM',
#  'CDM',
#  'RDM',
#  'RWB',
#  'LB',
#  'LCB',
#  'CB',
#  'RCB',
#  'RB']

# %%
skill = ['Crossing', 'Finishing', 'HeadingAccuracy','ShortPassing', 'Volleys', 'Dribbling', 'Curve', 'FKAccuracy','LongPassing', 'BallControl', 'Acceleration', 'SprintSpeed',
       'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping',
       'Stamina', 'Strength', 'LongShots', 'Aggression', 'Interceptions',
       'Positioning', 'Vision', 'Penalties', 'Composure', 'Marking',
       'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes']
skill
# Out:
# ['Crossing',
#  'Finishing',
#  'HeadingAccuracy',
#  'ShortPassing',
#  'Volleys',
#  'Dribbling',
#  'Curve',
#  'FKAccuracy',
#  'LongPassing',
#  'BallControl',
#  'Acceleration',
#  'SprintSpeed',
#  'Agility',
#  'Reactions',
#  'Balance',
#  'ShotPower',
#  'Jumping',
#  'Stamina',
#  'Strength',
#  'LongShots',
#  'Aggression',
#  'Interceptions',
#  'Positioning',
#  'Vision',
#  'Penalties',
#  'Composure',
#  'Marking',
#  'StandingTackle',
#  'SlidingTackle',
#  'GKDiving',
#  'GKHandling',
#  'GKKicking',
#  'GKPositioning',
#  'GKReflexes']

# %%
Rival_skill_94= df.loc[['L. Messi', 'Cristiano Ronaldo'], skill]
Rival_skill_94
# Out:
#                    Crossing  Finishing  HeadingAccuracy  ShortPassing  \
# Name
# L. Messi               84.0       95.0             70.0          90.0
# Cristiano Ronaldo      84.0       94.0             89.0          81.0
#
#                    Volleys  Dribbling  Curve  FKAccuracy  LongPassing  \
# Name
# L. Messi              86.0       97.0   93.0        94.0         87.0
# Cristiano Ronaldo     87.0       88.0   81.0        76.0         77.0
#
#                    BallControl  ...  Penalties  Composure  Marking  \
# Name                            ...
# L. Messi                  96.0  ...       75.0       96.0     33.0
# Cristiano Ronaldo         94.0  ...       85.0       95.0     28.0
#
#                    StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# Name
# L. Messi                     28.0           26.0       6.0        11.0
# Cristiano Ronaldo            31.0           23.0       7.0        11.0
#
#                    GKKicking  GKPositioning  GKReflexes
# ...

# %%
Rival94_Trans = Rival_skill_94.transpose()
Rival94_Trans.head()
# Out:
# Name             L. Messi  Cristiano Ronaldo
# Crossing             84.0               84.0
# Finishing            95.0               94.0
# HeadingAccuracy      70.0               89.0
# ShortPassing         90.0               81.0
# Volleys              86.0               87.0

# %%
Rival94_Trans.plot(kind='bar', figsize=(15, 8))
plt.title('Skill Comparison Lionel Messi vs Ronaldo')
plt.ylabel('Number Skill')
plt.xlabel('Skill')
plt.show()

# %% [markdown]
# Cristiano Ronaldo & Lionel Messi memiliki Overall Rating yang sama 94 namun atribut skill dari masing-masing individu memiliki perbedaan baik itu lebih baik ataupun lebih buruk

# %%
df.loc[['L. Messi', 'Cristiano Ronaldo'], position]
# Out:
#                      LS    ST    RS    LW    LF    CF    RF    RW   LAM   CAM  \
# Name
# L. Messi           88+2  88+2  88+2  92+2  93+2  93+2  93+2  92+2  93+2  93+2
# Cristiano Ronaldo  91+3  91+3  91+3  89+3  90+3  90+3  90+3  89+3  88+3  88+3
#
#                    ...   LWB   LDM   CDM   RDM   RWB    LB   LCB    CB   RCB  \
# Name               ...
# L. Messi           ...  64+2  61+2  61+2  61+2  64+2  59+2  47+2  47+2  47+2
# Cristiano Ronaldo  ...  65+3  61+3  61+3  61+3  65+3  61+3  53+3  53+3  53+3
#
#                      RB
# Name
# L. Messi           59+2
# Cristiano Ronaldo  61+3
#
# [2 rows x 26 columns]

# %%
df.loc['Cristiano Ronaldo', skill]
# Out:
# Crossing           84
# Finishing          94
# HeadingAccuracy    89
# ShortPassing       81
# Volleys            87
# Dribbling          88
# Curve              81
# FKAccuracy         76
# LongPassing        77
# BallControl        94
# Acceleration       89
# SprintSpeed        91
# Agility            87
# Reactions          96
# Balance            70
# ShotPower          95
# Jumping            95
# Stamina            88
# Strength           79
# LongShots          93
# Aggression         63
# Interceptions      29
# Positioning        95
# Vision             82
# Penalties          85
# Composure          95
# Marking            28
# StandingTackle     31
# SlidingTackle      23
# GKDiving            7
# GKHandling         11
# GKKicking          15
# GKPositioning      14
# GKReflexes         11
# Name: Cristiano Ronaldo, dtype: object

# %%
CR7_skill = df.loc['Cristiano Ronaldo', skill]
CR7_skill.plot(kind='line', figsize=(15, 8))

# %% [markdown]
# Skill yang dimiliki Cristiano Ronaldo di FIFA19 tidak cocok diposisikan sebagai Penjaga Gawang

# %%
df_ST_More80 =df[(df['Position']=='ST') & (df['Overall']>=80)]
df_ST_More80
# Out:
#                        ID  Age         Nationality  Overall  Potential  \
# Name
# Cristiano Ronaldo   20801   33            Portugal       94         94
# R. Lewandowski     188545   29              Poland       90         90
# H. Kane            202126   24             England       89         91
# S. Agüero          153079   30           Argentina       89         89
# G. Bale            173731   28               Wales       88         88
# M. Icardi          201399   25           Argentina       87         90
# R. Lukaku          192505   25             Belgium       87         89
# C. Immobile        192387   28               Italy       87         87
# A. Lacazette       193301   27              France       85         86
# E. Džeko           180930   32  Bosnia Herzegovina       85         85
# K. Benzema         165153   30              France       85         85
# M. Depay           202556   24         Netherlands       84         89
# ...

# %%
df_STMore80_byNation = df_ST_More80.groupby('Nationality', axis=0).sum()
df_STMore80_byNation
# Out:
#                          ID  Age  Overall  Potential  Special  \
# Nationality
# Argentina            354478   55      176        179     4047
# Belgium              397034   49      167        173     3912
# Bosnia Herzegovina   180930   32       85         85     1931
# Brazil              1012997  135      412        422     9884
# Cameroon             199069   26       80         82     1994
# Colombia             199110   27       80         81     1909
# Croatia              181783   32       84         84     2106
# DR Congo             198951   27       82         83     2010
# Dominican Republic   221639   24       80         85     2041
# England              636839  115      331        333     8210
# France              1025952  183      493        494    11907
# Germany              790615  103      326        334     8126
# Italy                192387   28       87         87     2009
# Netherlands          581429   80      247        252     5801
# ...

# %%
df_STMore80_byNation.sort_values(by='Overall', ascending=True, inplace=True)
df_top10ST_byNation = df_STMore80_byNation['Overall'].tail(10)
df_top10ST_byNation
# Out:
# Nationality
# Portugal        94
# Uruguay        160
# Belgium        167
# Argentina      176
# Netherlands    247
# Germany        326
# England        331
# Brazil         412
# France         493
# Spain          494
# Name: Overall, dtype: int64

# %%
df_top10ST_byNation.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Best Striker by Nation')
plt.title('Top 10 Nation has Best Striker More or Equal to 80 in Fifa 19')
for index, value in enumerate(df_top10ST_byNation):
    label = format(float(value)) 
    
    #plt.annotate(xy = label, color='white')
plt.show()

# %%
df_STMore80_byNation.sort_values(by='Overall', ascending=True, inplace=True)
df_top5ST_byNation = df_STMore80_byNation['Overall'].tail(5)
df_top5ST_byNation
# Out:
# Nationality
# Germany    326
# England    331
# Brazil     412
# France     493
# Spain      494
# Name: Overall, dtype: int64

# %%
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen']
explode_list = [0.1, 0, 0, 0, 0.1] # ratio for each continent with which to offset each wedge.

df_top5ST_byNation.plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%',
                            startangle=90,
                            shadow=True,
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Top 5 Striker by Nation in Fifa 19', y=1.12)

plt.axis('equal')

# add legend
plt.legend(labels=df_top5ST_byNation.index, loc='upper left')

plt.show()

# %%
Top10_Overall= df_STMore80_byNation['Overall'].describe()
Top10_Overall
# Out:
# count     20.00000
# mean     186.85000
# std      144.89498
# min       80.00000
# 25%       83.50000
# 50%       92.00000
# 75%      266.75000
# max      494.00000
# Name: Overall, dtype: float64

# %%
Top10_Overall.plot(kind='box', figsize=(7, 6))

plt.title('Box plot for Overall Equal or More than 80')
plt.ylabel('Number of Overall')

plt.show()

# %%
df.Value.replace('[\€,]', '', regex=True, inplace=True)
df['Value'].unique()
# Out:
# array(['110.5M', '77M', '118.5M', '72M', '102M', '93M', '67M', '80M',
#        '51M', '68M', '76.5M', '44M', '60M', '63M', '89M', '83.5M', '78M',
#        '58M', '53.5M', '51.5M', '38M', '64.5M', '27M', '81M', '69.5M',
#        '59.5M', '62M', '73.5M', '59M', '46M', '43M', '36M', '57M', '24M',
#        '30M', '4M', '64M', '30.5M', '62.5M', '52M', '45M', '34M', '46.5M',
#        '61M', '41.5M', '44.5M', '56.5M', '53M', '50M', '55M', '36.5M',
#        '45.5M', '43.5M', '35M', '39M', '18M', '21.5M', '50.5M', '54M',
#        '40.5M', '37.5M', '28.5M', '37M', '32M', '26M', '33M', '38.5M',
#        '35.5M', '9M', '15.5M', '22M', '14M', '42.5M', '31.5M', '42M',
#        '25M', '29.5M', '31M', '24.5M', '27.5M', '29M', '16.5M', '23M',
#        '19M', '4.2M', '40M', '41M', '28M', '22.5M', '34.5M', '32.5M',
#        '20M', '26.5M', '25.5M', '21M', '13M', '17.5M', '11.5M', '8M',
#        '6M', '19.5M', '6.5M', '20.5M', '23.5M', '18.5M', '17M', '12.5M',
# ...

# %%
df['Value'].replace(to_replace='[A-Za-z]+', value='', inplace=True, regex=True)
df['Value'].unique()
# Out:
# array(['110.5', '77', '118.5', '72', '102', '93', '67', '80', '51', '68',
#        '76.5', '44', '60', '63', '89', '83.5', '78', '58', '53.5', '51.5',
#        '38', '64.5', '27', '81', '69.5', '59.5', '62', '73.5', '59', '46',
#        '43', '36', '57', '24', '30', '4', '64', '30.5', '62.5', '52',
#        '45', '34', '46.5', '61', '41.5', '44.5', '56.5', '53', '50', '55',
#        '36.5', '45.5', '43.5', '35', '39', '18', '21.5', '50.5', '54',
#        '40.5', '37.5', '28.5', '37', '32', '26', '33', '38.5', '35.5',
#        '9', '15.5', '22', '14', '42.5', '31.5', '42', '25', '29.5', '31',
#        '24.5', '27.5', '29', '16.5', '23', '19', '4.2', '40', '41', '28',
#        '22.5', '34.5', '32.5', '20', '26.5', '25.5', '21', '13', '17.5',
#        '11.5', '8', '6', '19.5', '6.5', '20.5', '23.5', '18.5', '17',
#        '12.5', '15', '13.5', '4.8', '3', '1.5', '16', '10', '11', '7',
#        '14.5', '5.5', '10.5', '4.5', '12', '0', '9.5', '8.5', '2', '1.7',
# ...

# %%
df['Value']=df['Value'].astype(float)
df['Value'].unique()
# Out:
# array([110.5,  77. , 118.5,  72. , 102. ,  93. ,  67. ,  80. ,  51. ,
#         68. ,  76.5,  44. ,  60. ,  63. ,  89. ,  83.5,  78. ,  58. ,
#         53.5,  51.5,  38. ,  64.5,  27. ,  81. ,  69.5,  59.5,  62. ,
#         73.5,  59. ,  46. ,  43. ,  36. ,  57. ,  24. ,  30. ,   4. ,
#         64. ,  30.5,  62.5,  52. ,  45. ,  34. ,  46.5,  61. ,  41.5,
#         44.5,  56.5,  53. ,  50. ,  55. ,  36.5,  45.5,  43.5,  35. ,
#         39. ,  18. ,  21.5,  50.5,  54. ,  40.5,  37.5,  28.5,  37. ,
#         32. ,  26. ,  33. ,  38.5,  35.5,   9. ,  15.5,  22. ,  14. ,
#         42.5,  31.5,  42. ,  25. ,  29.5,  31. ,  24.5,  27.5,  29. ,
#         16.5,  23. ,  19. ,   4.2,  40. ,  41. ,  28. ,  22.5,  34.5,
#         32.5,  20. ,  26.5,  25.5,  21. ,  13. ,  17.5,  11.5,   8. ,
#          6. ,  19.5,   6.5,  20.5,  23.5,  18.5,  17. ,  12.5,  15. ,
#         13.5,   4.8,   3. ,   1.5,  16. ,  10. ,  11. ,   7. ,  14.5,
# ...

# %%
df['Value'].describe()
# Out:
# count    18207.000000
# mean       265.026929
# std        289.564928
# min          0.000000
# 25%          4.400000
# 50%        160.000000
# 75%        475.000000
# max        975.000000
# Name: Value, dtype: float64

# %%
df['Overall'].unique()
# Out:
# array([94, 92, 91, 90, 89, 88, 87, 86, 85, 84, 83, 82, 81, 80, 79, 78, 77,
#        76, 75, 74, 73, 72, 71, 70, 69, 68, 67, 66, 65, 64, 63, 62, 61, 60,
#        59, 58, 57, 56, 55, 54, 53, 52, 51, 50, 49, 48, 47, 46],
#       dtype=int64)

# %%
df[['Overall', 'Value']].groupby(['Overall'], as_index=False).mean()
# Out:
#     Overall       Value
# 0        46   60.000000
# 1        47   57.500000
# 2        48   49.062500
# 3        49   52.500000
# 4        50   49.514563
# 5        51   64.240000
# 6        52   82.578616
# 7        53   96.482412
# 8        54  111.760000
# 9        55  137.886792
# 10       56  137.492711
# 11       57  161.094527
# 12       58  185.022523
# 13       59  214.657143
# 14       60  292.241911
# 15       61  341.202532
# 16       62  382.146925
# 17       63  438.103792
# 18       64  514.782768
# 19       65  540.680478
# 20       66  558.413929
# 21       67  521.153936
# 22       68  432.891787
# 23       69  225.325797
# 24       70   51.207649
# 25       71   58.572925
# 26       72   36.860558
# 27       73   15.848026
# 28       74   12.632216
# 29       75   22.462374
# 30       76    8.966488
# 31       77   10.472368
# 32       78   10.757738
# 33       79   12.192982
# 34       80   13.511888
# 35       81   18.026882
# 36       82   20.875532
# ...

# %%
Overall_VS_Value = df[['Overall', 'Value']].groupby(['Overall'], as_index=True).mean()
Top10_Overall_VS_Value = Overall_VS_Value.tail(5)
Top10_Overall_VS_Value
# Out:
#               Value
# Overall
# 89        60.545455
# 90        65.100000
# 91        77.500000
# 92       118.500000
# 94        93.750000

# %%
Top10_Overall_VS_Value.plot(kind='line', figsize=(15, 8))

# %%
Top10_Overall_VS_Value.reset_index(inplace = True)

Top10_Overall_VS_Value.plot(kind='scatter', x='Overall', y='Value', figsize=(10, 6), color='darkblue')

plt.title('Overall vs Value')
plt.xlabel('Overall')
plt.ylabel('Value')

plt.show()
